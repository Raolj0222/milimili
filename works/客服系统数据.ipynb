# %%
import datetime
import sys
# path为tools的上层文件夹
sys.path.append('D:\milimili')
import numpy as np
import pandas as pd
import pymysql as ps
# 返回一个连接对象
conn = ps.connect(
    user="doomsday",
    password='doomsday2024-1',
    host="129.150.58.215",
    database="michat",
    port=3306
)

# %%
sql="""
select content,send_at from msg_store
where product_id = 94
and sender_role=1
"""

# %%
df=pd.read_sql(sql,conn)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6356\2690292919.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(sql,conn)

# %%
df['时间段']=df['send_at'].astype('str').str.slice(10,13).astype('int')+8

# %%
df.to_csv('msg_data.csv',index=False)

# %%
df.groupby(by='时间段',as_index=False)['content'].count().sort_values(by='content',ascending=False)
# Out:
#     时间段  content
# 6    14       69
# 10   18       42
# 3    11       39
# 8    16       35
# 7    15       32
# 2    10       30
# 11   19       27
# 15   23       26
# 9    17       26
# 4    12       19
# 13   21       18
# 14   22       12
# 1     9       12
# 5    13       11
# 12   20       10
# 17   25        9
# 22   30        7
# 0     8        7
# 16   24        7
# 19   27        5
# 21   29        4
# 20   28        3
# 18   26        2
# 23   31        2
